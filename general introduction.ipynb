# %% [markdown]
# <h1>operations on strings</h1>

# %%
z= "a"
print(z*10)
# Out:
# aaaaaaaaaa

# %%
lista = ['a', 'b',]

# %%
listb = ['here', 'iam', 'coding']

# %%
conct = lista + listb

# %%
print(conct)
# Out:
# ['a', 'b', 'here', 'iam', 'coding']

# %%
print(conct[::-1])
print(conct[-1::])
# Out:
# ['coding', 'iam', 'here', 'b', 'a']
# ['coding']

# %%
print(conct[1:])
# Out:
# ['b', 'here', 'iam', 'coding']

# %%
print(conct[:1])
# Out:
# ['a']

# %%
print(conct[::2])
# Out:
# ['a', 'here', 'coding']

# %%
listc = ['i', 'like','mango', 'and', 'other', 'fruits']
newconct = conct + listc

# %%
print(newconct)
# Out:
# ['a', 'b', 'here', 'iam', 'coding', 'i', 'like', 'mango', 'and', 'other', 'fruits']

# %%
print(newconct[2::])
# Out:
# ['here', 'iam', 'coding', 'i', 'like', 'mango', 'and', 'other', 'fruits']

# %%
print(newconct[2::3])
print(newconct[2:3])
# Out:
# ['here', 'i', 'and']
# ['here']

# %%
print(newconct)
# Out:
# ['a', 'b', 'here', 'iam', 'coding', 'i', 'like', 'mango', 'and', 'other', 'fruits']

# %%
print(newconct[::-1])
print(newconct[::-2])
print(newconct[:3])
print(newconct[1:8:3])
# Out:
# ['fruits', 'other', 'and', 'mango', 'like', 'i', 'coding', 'iam', 'here', 'b', 'a']
# ['fruits', 'and', 'like', 'coding', 'here', 'a']
# ['a', 'b', 'here']
# ['b', 'coding', 'mango']

# %%
for item in newconct:
    print(item)
# Out:
# a
# b
# here
# iam
# coding
# i
# like
# mango
# and
# other
# fruits

# %%
newconct.append(["dont", "forget", "my", "name", "davis"])

# %%
print(newconct)
# Out:
# ['a', 'b', 'here', 'iam', 'coding', 'i', 'like', 'mango', 'and', 'other', 'fruits', ['dont', 'forget', 'my', 'name', 'davis']]

# %%
print("hello worlk")
# Out:
# hello worlk

# %%
print("yeah")
# Out:
# yeah

# %%
print("lets staart")
# Out:
# lets staart

# %%
username = input("enter your first name")
